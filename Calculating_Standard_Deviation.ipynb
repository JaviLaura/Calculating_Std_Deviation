# %% [markdown]
# <a href="https://colab.research.google.com/github/JaviLaura/Calculating_Std_Deviation/blob/main/Calculating_Standard_Deviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<img src="https://static.junilearning.com/images/juni_logo.png" height=75 align=center hspace="5px"> **DS6 Project 1: Calculating Standard Deviation**

# %% [markdown]
# Create a DataFrame from the Height and Weight CSV file here: https://static.junilearning.com/python_data_science/height_and_weight.csv

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
HWdf = pd.read_csv("https://static.junilearning.com/python_data_science/height_and_weight.csv")
display(HWdf)
# Out:
#          Height    Weight
# 0      65.78331  112.9925
# 1      71.51521  136.4873
# 2      69.39874  153.0269
# 3      68.21660  142.3354
# 4      67.78781  144.2971
# ...         ...       ...
# 21838  69.76603  127.3629
# 21839  68.24223  124.3347
# 21840  68.84887  136.3807
# 21841  67.04484  127.0678
# 21842  70.93046  126.9017
#
# [21843 rows x 2 columns]

# %% [markdown]
# **Part 1: Calculate Standard Deviation**
#
# Write a function `std()` that takes in a DataFrame and the name of a column, and returns the standard deviation of all the data in that column.
#
# Test your function on the `Height` and `Weight` columns. Compare your answers to what pandas generates when you call `df.std()`
#
# ![picture](https://sohcahtoa.org.uk/oldblog/images/standarddeviationstandardalgorithm.png)

# %%
#Define a function that calculates the standard deviation with the formula in Project 1: Calculating Standard Deviation.
HWdf.std()
# Out:
# Height     1.899417
# Weight    11.667969
# dtype: float64

# %%
print(HWdf.loc[:,"Height"].std())
print(HWdf.loc[:,"Weight"].std())
# Out:
# 1.899417311598271
# 11.66796860414634

# %%
meanHeight = HWdf["Height"].mean()
meanWeight = HWdf["Weight"].mean()

print(meanHeight)
print(meanWeight)
# Out:
# 67.98766323215676
# 127.08980353889118

# %%
def std(df,colName):
  x_bar = df[colName].mean()
  sum = 0
  n = df[colName].count()
  for measurement in df[colName]:
    sum += (measurement - x_bar) ** 2
  
  return math.sqrt(sum/(n-1))


print(std(HWdf,"Height"))
print(std(HWdf,"Weight"))
# Out:
# 1.8994173115982695
# 11.667968604146285

# %% [markdown]
# **Part 2: Calculate Percent Values**
#
# Write a function `percentage()` that calculates the percentage of values in a distribution that fall between lower and upper bound.
#
# Then test your function and ensure that roughly 68% falls within 1 standard deviation of the mean, 96% falls within 2 standard deviations, and 99.7 falls within 3 standard deviations.

# %%
def percentage(df,colName,low,high):
  inRange = df[(df[colName]<high) & (df[colName]>low)]
  ratio = (inRange[colName].count())/(df[colName].count())
  percent = ratio * 100
  return str(round(ratio * 100,3)) + "%"

mean = HWdf["Height"].mean()
std = HWdf["Height"].std()

lowBound = mean - (2 * std)
highBound = mean + (2 * std)
#Replace num for as many std you want
print(percentage(HWdf,"Height",lowBound,highBound))
# Out:
# 95.486%

# %%
#Conditionals
df = pd.read_csv("https://static.junilearning.com/python_data_science/tips.csv")
display(df)
# Out:
#      total_bill   tip     sex   day
# 0         16.99  1.01  Female   Sun
# 1         10.34  1.66    Male   Sun
# 2         21.01  3.50    Male   Sun
# 3         23.68  3.31    Male   Sun
# 4         24.59  3.61  Female   Sun
# ..          ...   ...     ...   ...
# 239       29.03  5.92    Male   Sat
# 240       27.18  2.00  Female   Sat
# 241       22.67  2.00    Male   Sat
# 242       17.82  1.75    Male   Sat
# 243       18.78  3.00  Female  Thur
#
# [244 rows x 4 columns]

# %%
df[df["tip"]<2]
# Out:
#      total_bill   tip     sex   day
# 0         16.99  1.01  Female   Sun
# 1         10.34  1.66    Male   Sun
# 8         15.04  1.96    Male   Sun
# 10        10.27  1.71    Male   Sun
# 12        15.42  1.57    Male   Sun
# 16        10.33  1.67  Female   Sun
# 30         9.55  1.45    Male   Sat
# 43         9.68  1.32    Male   Sun
# 53         9.94  1.56    Male   Sun
# 57        26.41  1.50  Female   Sat
# 58        11.24  1.76    Male   Sat
# 62        11.02  1.98    Male   Sat
# 67         3.07  1.00  Female   Sat
# 70        12.02  1.97    Male   Sat
# 75        10.51  1.25    Male   Sat
# 82        10.07  1.83  Female  Thur
# 92         5.75  1.00  Female   Fri
# 97        12.03  1.50    Male   Fri
# 99        12.46  1.50    Male   Fri
# 105       15.36  1.64    Male   Sat
# 111        7.25  1.00  Female   Sat
# 117       10.65  1.50  Female  Thur
# 118       12.43  1.80  Female  Thur
# 121       13.42  1.68  Female  Thur
# 126        8.52  1.48    Male  Thur
# ...

# %%
df[(df["tip"]<2) & (df["day"] == "Sun")]
# Out:
#      total_bill   tip     sex  day
# 0         16.99  1.01  Female  Sun
# 1         10.34  1.66    Male  Sun
# 8         15.04  1.96    Male  Sun
# 10        10.27  1.71    Male  Sun
# 12        15.42  1.57    Male  Sun
# 16        10.33  1.67  Female  Sun
# 43         9.68  1.32    Male  Sun
# 53         9.94  1.56    Male  Sun
# 190       15.69  1.50    Male  Sun
